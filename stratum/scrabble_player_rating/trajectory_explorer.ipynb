# %%
# !ls .sempipes_trajectories
# Out:
# optimize2_20260209_221644_13679bf2.json
# optimize2_20260211_144429_39ff25fc.json

# %%
from sempipes.optimisers.trajectory import load_trajectory_from_json
# Out:
# 2026-02-11 15:02:30.439021: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1770818550.452862 4000061 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1770818550.457461 4000061 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1770818550.471459 4000061 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
base = ".sempipes_trajectories/"
trajectory = load_trajectory_from_json(base + "optimize2_20260209_221644_13679bf2.json")

# %%
outcomes = trajectory.outcomes
states = [outcomes[i].state for i in range(10)]

# %%
outcomes[0].search_node.memory
# Out:
# []

# %%
[o.search_node.memory for o in outcomes]
# Out:
# [[],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507}],
#  [{'update': '', 'score': -163.3879673125507},
# ...

# %%
states[1]
# Out:
# {'generated_code': ['',
# ...
